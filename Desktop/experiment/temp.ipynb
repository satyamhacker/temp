# %%
print("hii")

print("Hello, World!")

# !pip install langchain-community
# Out:
# hii
# Hello, World!
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0.0,>=1.0.1 (from langchain-community)
#   Downloading langchain_core-1.2.19-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.48-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from langchain-community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.3-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-community)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain-community)
#   Downloading langsmith-0.7.17-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=2.1.0 (from langchain-community)
#   Downloading numpy-2.4.3-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.1-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.23.0-cp313-cp313-win_amd64.whl.metadata (82 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.1->langchain-community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.0.1->langchain-community)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\satyam\Desktop\experiment\.venv\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Downloading greenlet-3.3.2-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 2.6 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.5 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 2.8 MB/s  0:00:00
# Downloading aiohttp-3.13.3-cp313-cp313-win_amd64.whl (453 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.8 MB/s  0:00:00
# Downloading langchain_core-1.2.19-py3-none-any.whl (503 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading langsmith-0.7.17-py3-none-any.whl (359 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp313-cp313-win_amd64.whl (45 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.7 MB/s  0:00:00
# Downloading pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Downloading sqlalchemy-2.0.48-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 2.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.6 MB/s  0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading yarl-1.23.0-cp313-cp313-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading greenlet-3.3.2-cp313-cp313-win_amd64.whl (230 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading numpy-2.4.3-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 2.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/12.3 MB 3.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.8/12.3 MB 3.5 MB/s eta 0:00:04
#    ------- -------------------------------- 2.4/12.3 MB 2.9 MB/s eta 0:00:04
#    --------- ------------------------------ 2.9/12.3 MB 2.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.7/12.3 MB 3.0 MB/s eta 0:00:03
#    ------------ --------------------------- 3.9/12.3 MB 2.8 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.3 MB 2.9 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.3 MB 2.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.3 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 6.0/12.3 MB 2.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.8/12.3 MB 2.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.3/12.3 MB 2.7 MB/s eta 0:00:02
#    ------------------------- -------------- 7.9/12.3 MB 2.7 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.3 MB 2.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.3 MB 2.7 MB/s eta 0:00:02
#    ------------------------------- -------- 9.7/12.3 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.3 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 2.7 MB/s  0:00:04
# Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl (124 kB)
# Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-inspection, tenacity, pydantic-core, propcache, orjson, numpy, mypy-extensions, multidict, marshmallow, jsonpatch, httpx-sse, greenlet, frozenlist, annotated-types, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, requests-toolbelt, pydantic, aiosignal, pydantic-settings, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-classic, langchain-community
#
#    ----------------------------------------  0/32 [zstandard]
#    --- ------------------------------------  3/32 [typing-inspection]
#    ----- ----------------------------------  4/32 [tenacity]
#    ----- ----------------------------------  4/32 [tenacity]
#    ------ ---------------------------------  5/32 [pydantic-core]
#    ------ ---------------------------------  5/32 [pydantic-core]
#    -------- -------------------------------  7/32 [orjson]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ---------- -----------------------------  8/32 [numpy]
#    ----------- ----------------------------  9/32 [mypy-extensions]
#    ------------- -------------------------- 11/32 [marshmallow]
#    ------------- -------------------------- 11/32 [marshmallow]
#    --------------- ------------------------ 12/32 [jsonpatch]
#    ---------------- ----------------------- 13/32 [httpx-sse]
#    ----------------- ---------------------- 14/32 [greenlet]
#    ----------------- ---------------------- 14/32 [greenlet]
#    ----------------- ---------------------- 14/32 [greenlet]
#    ----------------- ---------------------- 14/32 [greenlet]
#    ------------------ --------------------- 15/32 [frozenlist]
#    --------------------- ------------------ 17/32 [aiohappyeyeballs]
#    ---------------------- ----------------- 18/32 [yarl]
#    ---------------------- ----------------- 18/32 [yarl]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    ------------------------- -------------- 20/32 [SQLAlchemy]
#    -------------------------- ------------- 21/32 [requests-toolbelt]
#    -------------------------- ------------- 21/32 [requests-toolbelt]
#    -------------------------- ------------- 21/32 [requests-toolbelt]
#    -------------------------- ------------- 21/32 [requests-toolbelt]
#    -------------------------- ------------- 21/32 [requests-toolbelt]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    ------------------------------ --------- 24/32 [pydantic-settings]
#    ------------------------------ --------- 24/32 [pydantic-settings]
#    ------------------------------ --------- 24/32 [pydantic-settings]
#    ------------------------------ --------- 24/32 [pydantic-settings]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    ------------------------------- -------- 25/32 [langsmith]
#    -------------------------------- ------- 26/32 [dataclasses-json]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    --------------------------------- ------ 27/32 [aiohttp]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ----------------------------------- ---- 28/32 [langchain-core]
#    ------------------------------------ --- 29/32 [langchain-text-splitters]
#    ------------------------------------ --- 29/32 [langchain-text-splitters]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    ------------------------------------- -- 30/32 [langchain-classic]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    -------------------------------------- - 31/32 [langchain-community]
#    ---------------------------------------- 32/32 [langchain-community]
#
# Successfully installed SQLAlchemy-2.0.48 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 annotated-types-0.7.0 dataclasses-json-0.6.7 frozenlist-1.8.0 greenlet-3.3.2 httpx-sse-0.4.3 jsonpatch-1.33 langchain-classic-1.0.3 langchain-community-0.4.1 langchain-core-1.2.19 langchain-text-splitters-1.1.1 langsmith-0.7.17 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 numpy-2.4.3 orjson-3.11.7 propcache-0.4.1 pydantic-2.12.5 pydantic-core-2.41.5 pydantic-settings-2.13.1 requests-toolbelt-1.0.0 tenacity-9.1.4 typing-inspect-0.9.0 typing-inspection-0.4.2 uuid-utils-0.14.1 xxhash-3.6.0 yarl-1.23.0 zstandard-0.25.0

# %%
from langchain_ollama import ChatOllama

ollama_chat = ChatOllama(
    base_url="http://localhost:11434",
    model="llama3.1:8b",
    temperature=0.2,
    max_tokens=512
)

print(ollama_chat)
# Out:
# model='llama3.1:8b' temperature=0.2 base_url='http://localhost:11434'

# %%
from langchain.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful math tutor. Always explain step by step."),
    ("user", "Solve this problem: {question}")
])

formatted_prompt = prompt.invoke({"question": "What is 12 * 8?"})

print(formatted_prompt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from langchain.prompts import ChatPromptTemplate
#       3 prompt = ChatPromptTemplate.from_messages([
#       4     ("system", "You are a helpful math tutor. Always explain step by step."),
#       5     ("user", "Solve this problem: {question}")
#       6 ])
#       8 formatted_prompt = prompt.invoke({"question": "What is 12 * 8?"})
#
# ModuleNotFoundError: No module named 'langchain.prompts'
